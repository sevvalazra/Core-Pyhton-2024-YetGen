# %% [markdown]
# ### Soru 1
# Yazılımcıların bir dili öğrenmeye başladığında ilk yapacakları şey ekrana "Hello World" yazdırmaktır. Python'da da aynı şeyi yapalım.Bir yazılımcı aşağıdaki kodu yazarken hata yapıyor. Bunu düzelterek çalışan bir kod yazalım.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Soru 2
# İki YetGen'li zirvede karşılaşıyor. Zirvede birbirleriyle Python standında konuşurken YetGen Jump Python renginin ne olduğunu konuşurken bir YetGen lideri **logo** değişkenine atayıp ekrana bastırmalarını istiyor. Onlara bu noktada yardımcı olur musun?

# %%
logo = input("Rengi giriniz:")
print("YetGen Jump Python'un rengi:",logo)
# Out:
# YetGen Jump Python'un rengi: kırmızı

# %% [markdown]
# ### Soru 3
# Dairenin alanını hesaplayan bir Python kodu yazınız. pi sayısını 3.14 olarak alınız ve yarıçapını kullanıcıdan alınız. Sonucu ekrana bastırınız.

# %%
pi = 3.14
çap = float(input("dairenin çapını giriniz:"))
yarıçap = çap/2
alan = pi * yarıçap ** 2
print(alan)
# Out:
# 78.5

# %% [markdown]
# ### Soru 4
# x ve y adında iki liste oluşturunuz. Bu listeleri birbiryle yer değiştirerek yazdırınız.
#
# ```python
# x = [1,2,3,4,5]
# y = [5,4,3,2,1]
# ```
#
# ```python
# Output:
# x = [5, 4, 3, 2, 1]
# y = [1, 2, 3, 4, 5]
# ```

# %%
x = [1,2,3,4,5]
y = [5,4,3,2,1]
x.reverse()
y.reverse()
print("x =",x)
print("y =",y)
# Out:
# x = [5, 4, 3, 2, 1]
# y = [1, 2, 3, 4, 5]

# %% [markdown]
# ### Soru 5
# Aşağıda verilen kod satırının sonuncunu 1 olacak şekilde düzenleyiniz.

# %%
(5-3) // 2
# Out:
# 1

# %% [markdown]
# ### Soru 6
# Aşağıda verilen kod satırının sonucu 0 olacak şekilde düzenleyiniz.

# %%
(8-3) * (2-(1 + 1))
# Out:
# 0

# %% [markdown]
# ### Soru 7
# YetGen liderlerinden Berkcan,Emirhan  ve Eslem,Ramazan Bayramı'nda topladıkları şekerlerini bir araya getirmeyi ve kendi aralarında eşitolarak paylaşmayı kabul ettiler.Eşit paylaşım yapıldıktan sonra kalan şekerler parçalanacak.Örneğin eğer toplamda 91 şekerleri varsa ,hepsi 30 tane alıp kalan 1 tane şekeri parçalayacaklar.Kaç tane şekeri parçayacaklarını yazan bir pyhton kodunu yazınız.

# %%
# 7.Sorunun çözümünü buraya yazabilirsin.
Berkcan_candies = int(input("Berkcan'ın şeker sayısı :"))
Emirhan_candies = int(input("Emirhan'ın şeker sayısı :"))
Eslem_candies = int(input("BEslem'ın şeker sayısı :"))

candies_to_smash = (Berkcan_candies + Emirhan_candies + Eslem_candies) % 3
print(candies_to_smash)
# Out:
# 2
